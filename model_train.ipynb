# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/boat_detection")

# !pwd
# Out:
# /content/drive/MyDrive/boat_detection

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.2/910.2 kB 28.0 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !cat /root/.config/Ultralytics/settings.json
# Out:
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/content/drive/MyDrive/boat_detection/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }

# %%
os.chdir("/content/drive/MyDrive/boat_detection/datasets")

# !pwd
# Out:
# /content/drive/MyDrive/boat_detection/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="MbrwRQFG8nxVh7wtDzMq")
project = rf.workspace("iniciao-cientifica-levrq").project("boat-types-detection-h5oi6")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Boat-Types-Detection-2 in yolov11:: 100%|██████████| 5274/5274 [00:42<00:00, 123.63it/s]

# %%
os.chdir("/content/drive/MyDrive/boat_detection")

# !pwd
# Out:
# /content/drive/MyDrive/boat_detection

# %%
model = YOLO('yolo11m.pt')  # load a pretrained model (recommended for training)
results = model.train(data='/content/drive/MyDrive/boat_detection/datasets/Boat-Types-Detection-2/data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
